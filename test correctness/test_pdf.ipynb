# %%
from pdf_utils import *
from pathlib import Path

# =============================================================================
# PDF TEXT CLEANING DEMONSTRATION
# =============================================================================

# Define PDF file paths for testing
pdf_files = [
    "datafile/codice etico fittizio_Salute e sicurezza dei lavoratori.pdf",
    "datafile/BIS - Regolamento Aziendale.pdf", 
    "datafile/ccnl_commercio.pdf",
]

print("PDF TEXT CLEANING DEMONSTRATION")
print("=" * 60)

# =============================================================================
# PROCESS EACH PDF FILE
# =============================================================================

for file_idx, pdf_path in enumerate(pdf_files):
    print(f"\nProcessing file {file_idx + 1}/{len(pdf_files)}: {Path(pdf_path).name}")
    print("-" * 60)
    
    # Extract pages from current PDF
    pages = extract_pages(pdf_path)
    print(f"Extracted {len(pages)} pages from PDF")
    
    # Skip processing if no pages found
    if not pages:
        print("No pages found in PDF, skipping...")
        continue
    
    # =============================================================================
    # HEADER REMOVAL PROCESS
    # =============================================================================
    
    # Identify and remove common headers
    clean_headers, common_header_lines = remove_header(pages)
    print(f"\nHeader analysis results:")
    print(f"Common header lines identified: {len(common_header_lines)}")
    
    if common_header_lines:
        print("Header lines found:")
        for i, line in enumerate(sorted(common_header_lines), 1):
            print(f"  {i}. '{line}'")
    
    # =============================================================================
    # WHITESPACE CLEANING
    # =============================================================================
    
    # Clean excessive whitespace and newlines
    final_clean = [clean_whitespace(page) for page in clean_headers]
    
    # =============================================================================
    # CLEANING STATISTICS
    # =============================================================================
    
    # Calculate improvement statistics
    original_total_chars = sum(len(page) for page in pages)
    cleaned_total_chars = sum(len(page) for page in final_clean)
    reduction_percent = ((original_total_chars - cleaned_total_chars) / original_total_chars) * 100
    
    print(f"\nCleaning statistics:")
    print(f"Original total characters: {original_total_chars:,}")
    print(f"Cleaned total characters: {cleaned_total_chars:,}")
    print(f"Character reduction: {reduction_percent:.1f}%")
    
    # =============================================================================
    # BEFORE/AFTER COMPARISON FOR FIRST 8 PAGES
    # =============================================================================
    
    # Determine how many pages to show (max 8 or all available)
    pages_to_show = min(8, len(pages))
    print(f"\nBefore/After comparison (first and last 100 chars of first {pages_to_show} pages):")
    
    print("\nBEFORE - First 100 characters:")
    for page_idx in range(pages_to_show):
        print(f"  Page {page_idx + 1}: {repr(pages[page_idx][:100])}")
    
    print("\nAFTER - First 100 characters:")
    for page_idx in range(pages_to_show):
        print(f"  Page {page_idx + 1}: {repr(final_clean[page_idx][:100])}")
        
    print("\nBEFORE - Last 100 characters:")
    for page_idx in range(pages_to_show):
        page_content = pages[page_idx]
        last_chars = page_content[-100:] if len(page_content) > 100 else page_content
        print(f"  Page {page_idx + 1}: {repr(last_chars)}")
    
    print("\nAFTER - Last 100 characters:")
    for page_idx in range(pages_to_show):
        page_content = final_clean[page_idx]
        last_chars = page_content[-100:] if len(page_content) > 100 else page_content
        print(f"  Page {page_idx + 1}: {repr(last_chars)}")
    
    print(f"\nProcessing completed for {Path(pdf_path).name}")

print("\n" + "=" * 60)
print("All PDF files processed successfully")
# Out:
# PDF TEXT CLEANING DEMONSTRATION
# ============================================================
#
# Processing file 1/3: codice etico fittizio_Salute e sicurezza dei lavoratori.pdf
# ------------------------------------------------------------
# Extracted 1 pages from PDF
#
# Header analysis results:
# Common header lines identified: 0
#
# Cleaning statistics:
# Original total characters: 1,946
# Cleaned total characters: 1,905
# Character reduction: 2.1%
#
# Before/After comparison (first and last 100 chars of first 1 pages):
#
# BEFORE - First 100 characters:
#   Page 1: 'Salute e sicurezza sui luoghi di lavoro \n• Diritti del lavoratore \n \nL’Azienda si pone come obiettiv'
#
# AFTER - First 100 characters:
#   Page 1: 'Salute e sicurezza sui luoghi di lavoro\n• Diritti del lavoratore\nL’Azienda si pone come obiettivo pr'
#
# BEFORE - Last 100 characters:
#   Page 1: '\no quella dei colleghi. Evitando ad esempio di manomettere o rimuovere i dispositivi di \nsicurezza. '
#
# AFTER - Last 100 characters:
#   Page 1: 'za\no quella dei colleghi. Evitando ad esempio di manomettere o rimuovere i dispositivi di\nsicurezza.'
#
# Processing completed for codice etico fittizio_Salute e sicurezza dei lavoratori.pdf
#
# Processing file 2/3: BIS - Regolamento Aziendale.pdf
# ------------------------------------------------------------
# Extracted 4 pages from PDF
#
# Header analysis results:
# Common header lines identified: 0
#
# Cleaning statistics:
# Original total characters: 10,031
# Cleaned total characters: 9,094
# Character reduction: 9.3%
#
# Before/After comparison (first and last 100 chars of first 4 pages):
#
# BEFORE - First 100 characters:
#   Page 1: '                                                  \n  \n                \n \n \n \nREGOLAMENTO AZIENDALE \n'
#   Page 2: '                                                  \n  \n                \n \n \n \nper iscritto presso l’a'
#   Page 3: '                                                  \n  \n                \n \n \n \nL’assenza dal normale o'
#   Page 4: '                                                  \n  \n                \n \n \n \n16. Divieto di fumo e b'
#
# AFTER - First 100 characters:
#   Page 1: 'REGOLAMENTO AZIENDALE\n1. Applicabilità\nIl presente regolamento interno viene predisposto dall’aziend'
#   Page 2: 'per iscritto presso l’azienda entro 48 ore (ved. art. 7). Nel caso di assenze non giustificate sarà '
#   Page 3: 'L’assenza dal normale orario di lavoro senza l’autorizzazione di cui sopra, sarà considerata inademp'
#   Page 4: '16. Divieto di fumo e bevande alcoliche\nIl divieto di assumere bevande alcoliche è assoluto in quals'
#
# BEFORE - Last 100 characters:
#   Page 1: 'l’obbligo di dare immediata notizia dell’assenza all’azienda, le assenze devono essere giustificate '
#   Page 2: 'per la richiesta di ferie individuali e \ndovranno essere autorizzati a discrezione dell’azienda.  \n '
#   Page 3: 'rattasi di materiale a lui affidato in consegna, fatto salvo i casi di non imputabilità.  \n \n \n \n \n '
#   Page 4: '                                   \n            Pontecagnano Faiano 01/01/2024 \n \n \n \n \n \n \n \n \n \n \n'
#
# AFTER - Last 100 characters:
#   Page 1: ' l’obbligo di dare immediata notizia dell’assenza all’azienda, le assenze devono essere giustificate'
#   Page 2: 'iste per la richiesta di ferie individuali e\ndovranno essere autorizzati a discrezione dell’azienda.'
#   Page 3: 'todia, ove trattasi di materiale a lui affidato in consegna, fatto salvo i casi di non imputabilità.'
#   Page 4: 'e della sua\napplicazione è Giuseppe Gerardo Sessa.\nLuogo e data Firma\nPontecagnano Faiano 01/01/2024'
#
# Processing completed for BIS - Regolamento Aziendale.pdf
#
# Processing file 3/3: ccnl_commercio.pdf
# ------------------------------------------------------------
# Extracted 19 pages from PDF
#
# Header analysis results:
# Common header lines identified: 3
# Header lines found:
#   1. 'commercio, terziario, distribuzione e servizi'
#   2. 'contratto collettivo nazionale di lavoro'
#   3. 'il contenuto di questo contratto è di proprietà di conflavoro pmi – è severamente vietata la riproduzione in qualsiasi forma.'
#
# Cleaning statistics:
# Original total characters: 102,562
# Cleaned total characters: 97,128
# Character reduction: 5.3%
#
# Before/After comparison (first and last 100 chars of first 8 pages):
#
# BEFORE - First 100 characters:
#   Page 1: ' \n  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nCCNL \nContratto Collettivo Nazionale di Lavoro \n '
#   Page 2: ' \n \n \n2  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 3: ' \n \n \n3  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 4: ' \n \n \n4  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 5: ' \n \n \n5  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 6: ' \n \n \n6  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 7: ' \n \n \n7  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 8: ' \n \n \n8  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#
# AFTER - First 100 characters:
#   Page 1: 'CCNL\nContratto Collettivo Nazionale di Lavoro\nCommercio, Terziario, Distribuzione e Servizi\nIn vigor'
#   Page 2: 'In vigore dal 01/02/2023 al 31/01/2026\nL’anno 2023 il giorno 17 del mese di Gennaio in Roma, presso '
#   Page 3: 'SOMMARIO\n...........................................................................................'
#   Page 4: 'Art.25 bis – Contratto di reinserimento ............................................................'
#   Page 5: 'Art.55 - Durata rapporto contrattuale ..............................................................'
#   Page 6: 'Art.91 - Consistenza organico aziendale ............................................................'
#   Page 7: 'Art.123 - Commissione Nazionale di Certificazione Conciliazione ed Arbitrato .......................'
#   Page 8: 'Premessa\nIl presente Contratto Collettivo Nazionale di Lavoro Commercio, Terziario, Distribuzione e '
#
# BEFORE - Last 100 characters:
#   Page 1: '\nSottoscritto dalle parti sindacali \ndatoriali e dei lavoratori: \n \nCONFLAVORO PMI \nCONFSAL \nFESICA '
#   Page 2: ' Flaminia Mariani, Pasquale lnverno, \nVincenzo Minissale, Giuseppe Mancini, \nFrancesco di Matteo  \n '
#   Page 3: '................................................................................................ 20 '
#   Page 4: '................................................................................................ 33 '
#   Page 5: '.................................................................................................41 '
#   Page 6: '................................................................................................ 53 '
#   Page 7: '............................. ................................ ................................  64 '
#   Page 8: 'r tutta la sua durata,  deve \nessere considerato un complesso normativo unitario e inscindibile. \n  '
#
# AFTER - Last 100 characters:
#   Page 1: '01.2026\nSottoscritto dalle parti sindacali\ndatoriali e dei lavoratori:\nCONFLAVORO PMI\nCONFSAL\nFESICA'
#   Page 2: 'iello, Flaminia Mariani, Pasquale lnverno,\nVincenzo Minissale, Giuseppe Mancini,\nFrancesco di Matteo'
#   Page 3: '................................................................................................. 20'
#   Page 4: '................................................................................................. 33'
#   Page 5: '..................................................................................................41'
#   Page 6: '................................................................................................. 53'
#   Page 7: '............................... ................................ ................................ 64'
#   Page 8: 'he, per tutta la sua durata, deve\nessere considerato un complesso normativo unitario e inscindibile.'
#
# Processing completed for ccnl_commercio.pdf
#
# ============================================================
# All PDF files processed successfully
# Extracted 19 pages from PDF
#
# Header analysis results:
# Common header lines identified: 3
# Header lines found:
#   1. 'commercio, terziario, distribuzione e servizi'
#   2. 'contratto collettivo nazionale di lavoro'
#   3. 'il contenuto di questo contratto è di proprietà di conflavoro pmi – è severamente vietata la riproduzione in qualsiasi forma.'
#
# Cleaning statistics:
# Original total characters: 102,562
# Cleaned total characters: 97,128
# Character reduction: 5.3%
#
# Before/After comparison (first and last 100 chars of first 8 pages):
#
# BEFORE - First 100 characters:
#   Page 1: ' \n  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nCCNL \nContratto Collettivo Nazionale di Lavoro \n '
#   Page 2: ' \n \n \n2  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 3: ' \n \n \n3  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 4: ' \n \n \n4  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 5: ' \n \n \n5  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 6: ' \n \n \n6  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 7: ' \n \n \n7  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#   Page 8: ' \n \n \n8  \nContratto Collettivo Nazionale Di Lavoro \nCommercio, Terziario, Distribuzione e Servizi \nI'
#
# AFTER - First 100 characters:
#   Page 1: 'CCNL\nContratto Collettivo Nazionale di Lavoro\nCommercio, Terziario, Distribuzione e Servizi\nIn vigor'
#   Page 2: 'In vigore dal 01/02/2023 al 31/01/2026\nL’anno 2023 il giorno 17 del mese di Gennaio in Roma, presso '
#   Page 3: 'SOMMARIO\n...........................................................................................'
#   Page 4: 'Art.25 bis – Contratto di reinserimento ............................................................'
#   Page 5: 'Art.55 - Durata rapporto contrattuale ..............................................................'
#   Page 6: 'Art.91 - Consistenza organico aziendale ............................................................'
#   Page 7: 'Art.123 - Commissione Nazionale di Certificazione Conciliazione ed Arbitrato .......................'
#   Page 8: 'Premessa\nIl presente Contratto Collettivo Nazionale di Lavoro Commercio, Terziario, Distribuzione e '
#
# BEFORE - Last 100 characters:
#   Page 1: '\nSottoscritto dalle parti sindacali \ndatoriali e dei lavoratori: \n \nCONFLAVORO PMI \nCONFSAL \nFESICA '
#   Page 2: ' Flaminia Mariani, Pasquale lnverno, \nVincenzo Minissale, Giuseppe Mancini, \nFrancesco di Matteo  \n '
#   Page 3: '................................................................................................ 20 '
#   Page 4: '................................................................................................ 33 '
#   Page 5: '.................................................................................................41 '
#   Page 6: '................................................................................................ 53 '
#   Page 7: '............................. ................................ ................................  64 '
#   Page 8: 'r tutta la sua durata,  deve \nessere considerato un complesso normativo unitario e inscindibile. \n  '
#
# AFTER - Last 100 characters:
#   Page 1: '01.2026\nSottoscritto dalle parti sindacali\ndatoriali e dei lavoratori:\nCONFLAVORO PMI\nCONFSAL\nFESICA'
#   Page 2: 'iello, Flaminia Mariani, Pasquale lnverno,\nVincenzo Minissale, Giuseppe Mancini,\nFrancesco di Matteo'
#   Page 3: '................................................................................................. 20'
#   Page 4: '................................................................................................. 33'
#   Page 5: '..................................................................................................41'
#   Page 6: '................................................................................................. 53'
#   Page 7: '............................... ................................ ................................ 64'
#   Page 8: 'he, per tutta la sua durata, deve\nessere considerato un complesso normativo unitario e inscindibile.'
#
# Processing completed for ccnl_commercio.pdf
#
# ============================================================
# All PDF files processed successfully
